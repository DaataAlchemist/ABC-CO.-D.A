# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns



df = pd.read_csv(r"D:\Documents\empp.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Displaying basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB
# None

# %%
df.head(25)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder  Boston Celtics      99       SF   25  06-Jun
# 2              John Holland  Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter  Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson  Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey  Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk  Boston Celtics      41        C   25     7-0
# 8              Terry Rozier  Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart  Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger  Boston Celtics       7        C   24  06-Sep
# 11            Isaiah Thomas  Boston Celtics       4       PG   27  05-Sep
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df["College"].fillna("COLLEGE NOT FOUND",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.head(25)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder  Boston Celtics      99       SF   25  06-Jun
# 2              John Holland  Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter  Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson  Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey  Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk  Boston Celtics      41        C   25     7-0
# 8              Terry Rozier  Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart  Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger  Boston Celtics       7        C   24  06-Sep
# 11            Isaiah Thomas  Boston Celtics       4       PG   27  05-Sep
# ...

# %%
#Filling Mean in NaN Values 
df['Salary'].fillna(int(df['Salary'].mean()), inplace=True)

# %%
df.head(21)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder  Boston Celtics      99       SF   25  06-Jun
# 2              John Holland  Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter  Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson  Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey  Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk  Boston Celtics      41        C   25     7-0
# 8              Terry Rozier  Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart  Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger  Boston Celtics       7        C   24  06-Sep
# 11            Isaiah Thomas  Boston Celtics       4       PG   27  05-Sep
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.head(21)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25  06-Feb
# 1               Jae Crowder  Boston Celtics      99       SF   25  06-Jun
# 2              John Holland  Boston Celtics      30       SG   27  06-May
# 3               R.J. Hunter  Boston Celtics      28       SG   22  06-May
# 4             Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct
# 5              Amir Johnson  Boston Celtics      90       PF   29  06-Sep
# 6             Jordan Mickey  Boston Celtics      55       PF   21  06-Aug
# 7              Kelly Olynyk  Boston Celtics      41        C   25     7-0
# 8              Terry Rozier  Boston Celtics      12       PG   22  06-Feb
# 9              Marcus Smart  Boston Celtics      36       PG   22  06-Apr
# 10          Jared Sullinger  Boston Celtics       7        C   24  06-Sep
# 11            Isaiah Thomas  Boston Celtics       4       PG   27  05-Sep
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#Rectifying the error in 'Height' Coloumn

df['Height'] = np.random.randint(150, 181, size=len(df))

# %%
df.head(21)
# Out:
#                        Name            Team  Number Position  Age  Height  \
# 0             Avery Bradley  Boston Celtics       0       PG   25     175
# 1               Jae Crowder  Boston Celtics      99       SF   25     173
# 2              John Holland  Boston Celtics      30       SG   27     161
# 3               R.J. Hunter  Boston Celtics      28       SG   22     177
# 4             Jonas Jerebko  Boston Celtics       8       PF   29     155
# 5              Amir Johnson  Boston Celtics      90       PF   29     156
# 6             Jordan Mickey  Boston Celtics      55       PF   21     159
# 7              Kelly Olynyk  Boston Celtics      41        C   25     162
# 8              Terry Rozier  Boston Celtics      12       PG   22     160
# 9              Marcus Smart  Boston Celtics      36       PG   22     153
# 10          Jared Sullinger  Boston Celtics       7        C   24     170
# 11            Isaiah Thomas  Boston Celtics       4       PG   27     176
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %% [markdown]
# # 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
T_count= df['Team'].value_counts()
per_split = T_count/ len(df) * 100
df1= pd.DataFrame({'Count': T_count, 'Percentage': per_split})
df1
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# New York Knicks            16    3.493450
# Milwaukee Bucks            16    3.493450
# Brooklyn Nets              15    3.275109
# Portland Trail Blazers     15    3.275109
# Oklahoma City Thunder      15    3.275109
# Denver Nuggets             15    3.275109
# Washington Wizards         15    3.275109
# Miami Heat                 15    3.275109
# Charlotte Hornets          15    3.275109
# Atlanta Hawks              15    3.275109
# San Antonio Spurs          15    3.275109
# Houston Rockets            15    3.275109
# Boston Celtics             15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Sacramento Kings           15    3.275109
# ...

# %% [markdown]
# # 2.Segregate the employees w.r.t different positions.

# %%
import matplotlib.pyplot as plt

df1['Percentage'].plot.pie(figsize=(10,10), autopct='%1.1f%%', startangle=90, radius=1.2)
plt.title("Employees as per Team", fontsize=16, y=1.08)
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %%
df4=df.groupby("Position")["Name"].nunique()

# %%
df4.plot.pie(y="Number",autopct='%1.1f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %%
df5=df.groupby("Position")
df5.describe()
# Out:
#          Number                                                       Age  \
#           count       mean        std  min   25%   50%   75%   max  count
# Position
# C          79.0  21.962025  16.612046  0.0  11.5  17.0  29.5  92.0   79.0
# PF        100.0  23.570000  20.107918  0.0   6.0  21.5  35.0  90.0  100.0
# PG         92.0  10.967391  11.982085  0.0   2.0   8.0  14.0  55.0   92.0
# SF         85.0  17.611765  14.904533  0.0   7.0  15.0  24.0  99.0   85.0
# SG        102.0  14.852941  11.497221  0.0   5.0  11.0  23.0  55.0  102.0
#
#                      ... Weight        Salary                              \
#                mean  ...    75%    max  count          mean           std
# Position             ...
# C         27.341772  ...  265.0  307.0   79.0  5.903511e+06  5.778432e+06
# PF        27.160000  ...  250.0  275.0  100.0  4.570628e+06  4.726995e+06
# PG        26.847826  ...  200.0  220.0   92.0  5.067227e+06  4.939786e+06
# ...

# %% [markdown]
# # 3.Find from which age group most of the employees belong to.

# %%
age=df['Age'].value_counts().head(30)
age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Age",data=df)
plt.title("Age Group Category")
plt.show()

# %%
bins= [15,20,25,30,35,40]
labels=["15-20","21-25","26-30","31-35","36-40"]
df["Age_Group"]=pd.cut(df["Age"],bins=bins,labels=labels)
sns.countplot(x="Age_Group",data=df)
plt.title("Age Group Category")
plt.show()

# %% [markdown]
# # 4. Find out under which team and position, spending in terms of salary is high.

# %%
df_ts=pd.DataFrame(df.groupby(["Team","Position"])["Salary"].sum())
df_ts
# Out:
#                                  Salary
# Team               Position
# Atlanta Hawks      C         22756250.0
#                    PF        23952268.0
#                    PG         9763400.0
#                    SF         6000000.0
#                    SG        10431032.0
# ...                                 ...
# Washington Wizards C         24490429.0
#                    PF        11300000.0
#                    PG        18022415.0
#                    SF        11158800.0
#                    SG        11356992.0
#
# [149 rows x 1 columns]

# %%
df_ts.sort_values(by="Salary", ascending=False)
# Out:
#                                  Salary
# Team               Position
# Los Angeles Lakers SF        31866445.0
# Miami Heat         PF        31538671.0
# Houston Rockets    SG        28122883.0
# Phoenix Suns       PG        28002998.0
# Denver Nuggets     SF        27982771.0
# ...                                 ...
# Milwaukee Bucks    SF         3104287.0
# Philadelphia 76ers SF         1845059.0
# Sacramento Kings   PF         1370152.0
# Miami Heat         C           981348.0
# Orlando Magic      SF          845059.0
#
# [149 rows x 1 columns]

# %%
df_ts.sort_values(by="Salary", ascending=False).head(1)
# Out:
#                                  Salary
# Team               Position
# Los Angeles Lakers SF        31866445.0

# %% [markdown]
# # 5 Visual correlation Representation between Age and Salary

# %%
sns.scatterplot(x="Age", y="Salary", data=df)
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Correlation between age and salary")
plt.grid()
plt.show()

# %%
df.to_csv("Mod1_End_prjt_final.csv")
